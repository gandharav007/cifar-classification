# %%
import keras
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
#from keras.datasets import cifar10
from keras import regularizers
from keras.callbacks import LearningRateScheduler
import matplotlib.pyplot as plt
import numpy as np
import cifar10
 
def lr_schedule(epoch):
    lrate = 0.001
    if epoch > 75:
        lrate = 0.0005
    if epoch > 100:
        lrate = 0.0003
    return lrate
 
x_train, y_train, train_label= cifar10.load_training_data()
x_test, y_test,test_label=cifar10.load_test_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
#plt.plot(x_train[0]) 
#z-score
mean = np.mean(x_train,axis=(0,1,2,3))
std = np.std(x_train,axis=(0,1,2,3))
x_train = (x_train-mean)/(std+1e-7)
x_test = (x_test-mean)/(std+1e-7)
 
num_classes = 10
y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)
 
weight_decay = 1e-4
model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:]))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
 
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))
 
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))
 
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
 
model.summary()
 
#data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    )
datagen.fit(x_train)
 
#training
batch_size = 64
 
opt_rms = keras.optimizers.rmsprop(lr=0.001,decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt_rms, metrics=['accuracy'])
model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),\
                    steps_per_epoch=x_train.shape[0] // batch_size,epochs=10,\
                    verbose=1,validation_data=(x_test,y_test),callbacks=[LearningRateScheduler(lr_schedule)])
#save to disk
model_json = model.to_json()
with open('model.json', 'w') as json_file:
    json_file.write(model_json)
model.save_weights('model.h5') 
y_pred=model.predict(x_test)
#testing
# Out:
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_1
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_2
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_3
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_4
# Loading data: data/CIFAR-10/cifar-10-batches-py/data_batch_5
# Loading data: data/CIFAR-10/cifar-10-batches-py/test_batch
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_19 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_20 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_21 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_22 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_23 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_24 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/10
# 781/781 [==============================] - 30s 39ms/step - loss: 1.9198 - accuracy: 0.4164 - val_loss: 1.6398 - val_accuracy: 0.5069
# Epoch 2/10
# 781/781 [==============================] - 27s 35ms/step - loss: 1.2720 - accuracy: 0.5846 - val_loss: 1.0531 - val_accuracy: 0.6717
# Epoch 3/10
# 781/781 [==============================] - 28s 35ms/step - loss: 1.0661 - accuracy: 0.6549 - val_loss: 0.9838 - val_accuracy: 0.6946
# Epoch 4/10
# 781/781 [==============================] - 29s 37ms/step - loss: 0.9681 - accuracy: 0.6928 - val_loss: 0.8765 - val_accuracy: 0.7326
# Epoch 5/10
# 781/781 [==============================] - 28s 36ms/step - loss: 0.9019 - accuracy: 0.7174 - val_loss: 0.8953 - val_accuracy: 0.7336
# Epoch 6/10
# 781/781 [==============================] - 28s 36ms/step - loss: 0.8528 - accuracy: 0.7381 - val_loss: 0.8553 - val_accuracy: 0.7506
# Epoch 7/10
# 781/781 [==============================] - 29s 37ms/step - loss: 0.8182 - accuracy: 0.7517 - val_loss: 0.7787 - val_accuracy: 0.7771
# Epoch 8/10
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7951 - accuracy: 0.7626 - val_loss: 0.7794 - val_accuracy: 0.7796
# Epoch 9/10
# 781/781 [==============================] - 29s 37ms/step - loss: 0.7680 - accuracy: 0.7709 - val_loss: 0.7519 - val_accuracy: 0.7855
# Epoch 10/10
# 781/781 [==============================] - 28s 36ms/step - loss: 0.7541 - accuracy: 0.7806 - val_loss: 0.7154 - val_accuracy: 0.7993

# %%
#checking test results
scores = model.evaluate(x_test, y_test, batch_size=128, verbose=1)
print('\nTest result: %.3f loss: %.3f' % (scores[1]*100,scores[0]))
# Out:
# 10000/10000 [==============================] - 2s 156us/step
#
# Test result: 79.930 loss: 0.715

# %%
import pandas as pd
labels =  ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
indices = np.argmax(y_pred,1)
y_final=[labels[x] for x in indices]
pd.DataFrame([labels[x] for x in indices]).to_csv('cifar10_prediction.csv',header=None,index=False)

# %%
y_final
# Out:
# ['ship',
#  'automobile',
#  'automobile',
#  'ship',
#  'frog',
#  'frog',
#  'automobile',
#  'frog',
#  'cat',
#  'truck',
#  'airplane',
#  'truck',
#  'frog',
#  'automobile',
#  'truck',
#  'ship',
#  'dog',
#  'truck',
#  'ship',
#  'frog',
#  'horse',
#  'airplane',
#  'deer',
#  'truck',
#  'deer',
#  'truck',
#  'deer',
#  'airplane',
#  'truck',
#  'frog',
#  'frog',
#  'dog',
#  'bird',
#  'cat',
#  'truck',
#  'automobile',
#  'deer',
#  'automobile',
#  'truck',
#  'dog',
#  'airplane',
#  'frog',
#  'dog',
#  'frog',
#  'airplane',
#  'truck',
#  'cat',
#  'truck',
#  'deer',
#  'frog',
#  'truck',
#  'ship',
#  'horse',
#  'frog',
#  'ship',
#  'ship',
#  'truck',
#  'cat',
#  'deer',
#  'cat',
#  'horse',
#  'dog',
#  'frog',
#  'airplane',
#  'frog',
#  'frog',
#  'automobile',
#  'airplane',
#  'cat',
#  'truck',
#  'airplane',
#  'frog',
#  'ship',
#  'ship',
#  'truck',
#  'bird',
#  'airplane',
#  'ship',
#  'dog',
#  'ship',
#  'ship',
#  'automobile',
#  'automobile',
#  'horse',
#  'bird',
#  'truck',
#  'truck',
#  'ship',
#  'ship',
#  'truck',
#  'airplane',
#  'frog',
#  'ship',
#  'frog',
#  'deer',
#  'frog',
#  'frog',
#  'airplane',
#  'airplane',
#  'horse',
#  'deer',
#  'frog',
#  'frog',
#  'cat',
#  'automobile',
#  'automobile',
#  'bird',
#  'frog',
#  'ship',
#  'horse',
#  'deer',
#  'airplane',
#  'frog',
#  'bird',
#  'automobile',
#  'cat',
#  'airplane',
#  'cat',
#  'frog',
#  'horse',
#  'ship',
#  'cat',
#  'automobile',
#  'bird',
#  'ship',
#  'airplane',
#  'ship',
#  'cat',
#  'dog',
#  'airplane',
#  'deer',
#  'automobile',
#  'ship',
#  'truck',
#  'automobile',
#  'bird',
#  'truck',
#  'truck',
#  'deer',
#  'ship',
#  'frog',
#  'dog',
#  'frog',
#  'truck',
#  'ship',
#  'bird',
#  'frog',
#  'frog',
#  'dog',
#  'dog',
#  'automobile',
#  'truck',
#  'frog',
#  'airplane',
#  'airplane',
#  'frog',
#  'bird',
#  'truck',
#  'cat',
#  'airplane',
#  'airplane',
#  'automobile',
#  'automobile',
#  'frog',
#  'airplane',
#  'airplane',
#  'ship',
#  'frog',
#  'cat',
#  'airplane',
#  'truck',
#  'truck',
#  'truck',
#  'ship',
#  'truck',
#  'truck',
#  'dog',
#  'horse',
#  'cat',
#  'truck',
#  'ship',
#  'dog',
#  'bird',
#  'frog',
#  'airplane',
#  'ship',
#  'frog',
#  'cat',
#  'cat',
#  'airplane',
#  'frog',
#  'ship',
#  'truck',
#  'automobile',
#  'horse',
#  'deer',
#  'ship',
#  'ship',
#  'horse',
#  'ship',
#  'cat',
#  'automobile',
#  'ship',
#  'truck',
#  'automobile',
#  'cat',
#  'airplane',
#  'dog',
#  'horse',
#  'truck',
#  'dog',
#  'automobile',
#  'dog',
#  'truck',
#  'ship',
#  'airplane',
#  'airplane',
#  'truck',
#  'ship',
#  'bird',
#  'horse',
#  'cat',
#  'truck',
#  'deer',
#  'deer',
#  'truck',
#  'automobile',
#  'deer',
#  'cat',
#  'frog',
#  'dog',
#  'automobile',
#  'horse',
#  'ship',
#  'ship',
#  'airplane',
#  'deer',
#  'truck',
#  'dog',
#  'dog',
#  'automobile',
#  'automobile',
#  'automobile',
#  'truck',
#  'airplane',
#  'automobile',
#  'automobile',
#  'ship',
#  'bird',
#  'airplane',
#  'horse',
#  'truck',
#  'truck',
#  'truck',
#  'deer',
#  'ship',
#  'cat',
#  'airplane',
#  'ship',
#  'truck',
#  'truck',
#  'truck',
#  'dog',
#  'cat',
#  'airplane',
#  'ship',
#  'ship',
#  'deer',
#  'horse',
#  'airplane',
#  'bird',
#  'cat',
#  'frog',
#  'dog',
#  'ship',
#  'dog',
#  'automobile',
#  'truck',
#  'deer',
#  'truck',
#  'truck',
#  'automobile',
#  'frog',
#  'automobile',
#  'truck',
#  'truck',
#  'automobile',
#  'ship',
#  'horse',
#  'truck',
#  'automobile',
#  'bird',
#  'frog',
#  'truck',
#  'cat',
#  'deer',
#  'frog',
#  'airplane',
#  'airplane',
#  'frog',
#  'frog',
#  'frog',
#  'cat',
#  'automobile',
#  'frog',
#  'automobile',
#  'truck',
#  'bird',
#  'automobile',
#  'deer',
#  'ship',
#  'frog',
#  'airplane',
#  'cat',
#  'horse',
#  'dog',
#  'horse',
#  'horse',
#  'dog',
#  'dog',
#  'cat',
#  'cat',
#  'bird',
#  'bird',
#  'horse',
#  'automobile',
#  'horse',
#  'dog',
#  'deer',
#  'frog',
#  'automobile',
#  'truck',
#  'cat',
#  'frog',
#  'frog',
#  'truck',
#  'cat',
#  'ship',
#  'airplane',
#  'automobile',
#  'bird',
#  'frog',
#  'airplane',
#  'horse',
#  'ship',
#  'dog',
#  'deer',
#  'frog',
#  'ship',
#  'truck',
#  'truck',
#  'automobile',
#  'airplane',
#  'airplane',
#  'frog',
#  'frog',
#  'deer',
#  'bird',
#  'automobile',
#  'airplane',
#  'truck',
#  'dog',
#  'ship',
#  'automobile',
#  'truck',
#  'airplane',
#  'automobile',
#  'deer',
#  'deer',
#  'automobile',
#  'deer',
#  'horse',
#  'truck',
#  'deer',
#  'bird',
#  'horse',
#  'truck',
#  'truck',
#  'airplane',
#  'frog',
#  'frog',
#  'truck',
#  'airplane',
#  'airplane',
#  'dog',
#  'ship',
#  'horse',
#  'bird',
#  'dog',
#  'horse',
#  'automobile',
#  'airplane',
#  'frog',
#  'bird',
#  'truck',
#  'frog',
#  'bird',
#  'cat',
#  'airplane',
#  'truck',
#  'truck',
#  'automobile',
#  'automobile',
#  'ship',
#  'ship',
#  'frog',
#  'airplane',
#  'automobile',
#  'ship',
#  'dog',
#  'horse',
#  'airplane',
#  'dog',
#  'frog',
#  'automobile',
#  'truck',
#  'airplane',
#  'airplane',
#  'horse',
#  'horse',
#  'deer',
#  'cat',
#  'ship',
#  'dog',
#  'bird',
#  'truck',
#  'frog',
#  'deer',
#  'truck',
#  'frog',
#  'deer',
#  'dog',
#  'ship',
#  'horse',
#  'truck',
#  'horse',
#  'frog',
#  'dog',
#  'dog',
#  'truck',
#  'automobile',
#  'deer',
#  'truck',
#  'truck',
#  'cat',
#  'truck',
#  'dog',
#  'airplane',
#  'bird',
#  'airplane',
#  'truck',
#  'truck',
#  'horse',
#  'deer',
#  'truck',
#  'deer',
#  'deer',
#  'horse',
#  'frog',
#  'truck',
#  'dog',
#  'frog',
#  'automobile',
#  'deer',
#  'truck',
#  'deer',
#  'deer',
#  'cat',
#  'horse',
#  'ship',
#  'cat',
#  'horse',
#  'ship',
#  'ship',
#  'dog',
#  'horse',
#  'frog',
#  'truck',
#  'dog',
#  'deer',
#  'truck',
#  'frog',
#  'ship',
#  'automobile',
#  'dog',
#  'truck',
#  'truck',
#  'truck',
#  'truck',
#  'airplane',
#  'automobile',
#  'airplane',
#  'ship',
#  'automobile',
#  'automobile',
#  'ship',
#  'airplane',
#  'bird',
#  'airplane',
#  'airplane',
#  'deer',
#  'frog',
#  'dog',
#  'deer',
#  'truck',
#  'deer',
#  'horse',
#  'truck',
#  'truck',
#  'deer',
#  'dog',
#  'frog',
#  'frog',
#  'automobile',
#  'dog',
#  'frog',
#  'ship',
#  'truck',
#  'cat',
#  'ship',
#  'dog',
#  'horse',
#  'airplane',
#  'horse',
#  'airplane',
#  'ship',
#  'airplane',
#  'airplane',
#  'airplane',
#  'frog',
#  'truck',
#  'truck',
#  'truck',
#  'dog',
#  'frog',
#  'frog',
#  'frog',
#  'bird',
#  'truck',
#  'truck',
#  'automobile',
#  'deer',
#  'frog',
#  'horse',
#  'dog',
#  'truck',
#  'automobile',
#  'frog',
#  'truck',
#  'cat',
#  'dog',
#  'bird',
#  'automobile',
#  'dog',
#  'truck',
#  'deer',
#  'frog',
#  'deer',
#  'cat',
#  'bird',
#  'airplane',
#  'horse',
#  'frog',
#  'deer',
#  'deer',
#  'truck',
#  'truck',
#  'dog',
#  'truck',
#  'deer',
#  'frog',
#  'horse',
#  'automobile',
#  'automobile',
#  'frog',
#  'frog',
#  'ship',
#  'ship',
#  'horse',
#  'truck',
#  'deer',
#  'bird',
#  'ship',
#  'truck',
#  'airplane',
#  'automobile',
#  'frog',
#  'deer',
#  'ship',
#  'truck',
#  'frog',
#  'truck',
#  'bird',
#  'frog',
#  'automobile',
#  'deer',
#  'horse',
#  'truck',
#  'dog',
#  'cat',
#  'ship',
#  'dog',
#  'airplane',
#  'bird',
#  'automobile',
#  'frog',
#  'truck',
#  'dog',
#  'cat',
#  'truck',
#  'frog',
#  'truck',
#  'ship',
#  'ship',
#  'dog',
#  'truck',
#  'frog',
#  'frog',
#  'bird',
#  'automobile',
#  'horse',
#  'automobile',
#  'automobile',
#  'truck',
#  'horse',
#  'truck',
#  'automobile',
#  'truck',
#  'deer',
#  'automobile',
#  'airplane',
#  'dog',
#  'frog',
#  'ship',
#  'horse',
#  'frog',
#  'ship',
#  'deer',
#  'airplane',
#  'truck',
#  'dog',
#  'frog',
#  'airplane',
#  'horse',
#  'automobile',
#  'automobile',
#  'cat',
#  'deer',
#  'deer',
#  'dog',
#  'cat',
#  'truck',
#  'truck',
#  'frog',
#  'truck',
#  'airplane',
#  'automobile',
#  'automobile',
#  'deer',
#  'automobile',
#  'truck',
#  'horse',
#  'horse',
#  'frog',
#  'cat',
#  'airplane',
#  'truck',
#  'airplane',
#  'automobile',
#  'dog',
#  'frog',
#  'cat',
#  'ship',
#  'cat',
#  'bird',
#  'airplane',
#  'deer',
#  'automobile',
#  'automobile',
#  'dog',
#  'truck',
#  'frog',
#  'ship',
#  'automobile',
#  'truck',
#  'deer',
#  'truck',
#  'frog',
#  'frog',
#  'deer',
#  'deer',
#  'bird',
#  'airplane',
#  'horse',
#  'ship',
#  'cat',
#  'airplane',
#  'airplane',
#  'horse',
#  'dog',
#  'horse',
#  'airplane',
#  'deer',
#  'ship',
#  'horse',
#  'deer',
#  'airplane',
#  'truck',
#  'ship',
#  'ship',
#  'frog',
#  'airplane',
#  'ship',
#  'horse',
#  'deer',
#  'cat',
#  'cat',
#  'truck',
#  'horse',
#  'truck',
#  'horse',
#  'ship',
#  'ship',
#  'automobile',
#  'ship',
#  'cat',
#  'automobile',
#  'cat',
#  'frog',
#  'dog',
#  'dog',
#  'airplane',
#  'horse',
#  'truck',
#  'automobile',
#  'bird',
#  'automobile',
#  'ship',
#  'automobile',
#  'horse',
#  'dog',
#  'horse',
#  'airplane',
#  'horse',
#  'automobile',
#  'horse',
#  'deer',
#  'frog',
#  'bird',
#  'cat',
#  'truck',
#  'airplane',
#  'truck',
#  'automobile',
#  'bird',
#  'bird',
#  'frog',
#  'ship',
#  'bird',
#  'automobile',
#  'truck',
#  'dog',
#  'truck',
#  'airplane',
#  'automobile',
#  'bird',
#  'airplane',
#  'truck',
#  'bird',
#  'airplane',
#  'automobile',
#  'truck',
#  'frog',
#  'frog',
#  'airplane',
#  'frog',
#  'horse',
#  'frog',
#  'airplane',
#  'frog',
#  'truck',
#  'automobile',
#  'horse',
#  'frog',
#  'automobile',
#  'airplane',
#  'cat',
#  'truck',
#  'frog',
#  'ship',
#  'airplane',
#  'airplane',
#  'automobile',
#  'dog',
#  'horse',
#  'dog',
#  'truck',
#  'deer',
#  'cat',
#  'deer',
#  'horse',
#  'automobile',
#  'bird',
#  'horse',
#  'deer',
#  'deer',
#  'ship',
#  'frog',
#  'horse',
#  'truck',
#  'dog',
#  'dog',
#  'horse',
#  'bird',
#  'truck',
#  'ship',
#  'truck',
#  'cat',
#  'automobile',
#  'automobile',
#  'frog',
#  'bird',
#  'airplane',
#  'ship',
#  'horse',
#  'dog',
#  'airplane',
#  'frog',
#  'dog',
#  'dog',
#  'automobile',
#  'truck',
#  'bird',
#  'bird',
#  'deer',
#  'truck',
#  'airplane',
#  'bird',
#  'truck',
#  'bird',
#  'horse',
#  'airplane',
#  'horse',
#  'bird',
#  'automobile',
#  'airplane',
#  'bird',
#  'airplane',
#  'frog',
#  'deer',
#  'horse',
#  'truck',
#  'truck',
#  'automobile',
#  'airplane',
#  'truck',
#  'horse',
#  'airplane',
#  'horse',
#  'ship',
#  'deer',
#  'frog',
#  'frog',
#  'dog',
#  'airplane',
#  'automobile',
#  'automobile',
#  'horse',
#  'airplane',
#  'automobile',
#  'cat',
#  'automobile',
#  'cat',
#  'airplane',
#  'cat',
#  'ship',
#  'deer',
#  'dog',
#  'deer',
#  'horse',
#  'ship',
#  'deer',
#  'airplane',
#  'airplane',
#  'truck',
#  'airplane',
#  'truck',
#  'automobile',
#  'automobile',
#  'frog',
#  'deer',
#  'frog',
#  'dog',
#  'cat',
#  'automobile',
#  'automobile',
#  'truck',
#  'horse',
#  'dog',
#  'dog',
#  'frog',
#  'frog',
#  'frog',
#  'dog',
#  'ship',
#  'horse',
#  'automobile',
#  'frog',
#  'ship',
#  'ship',
#  'horse',
#  'cat',
#  'automobile',
#  'deer',
#  'airplane',
#  'automobile',
#  'deer',
#  'ship',
#  'ship',
#  'airplane',
#  'frog',
#  'truck',
#  'truck',
#  'truck',
#  'airplane',
#  'dog',
#  'ship',
#  'frog',
#  'airplane',
#  'ship',
#  'deer',
#  'bird',
#  'automobile',
#  'dog',
#  'horse',
#  'cat',
#  'cat',
#  'dog',
#  'automobile',
#  'ship',
#  'truck',
#  'automobile',
#  'horse',
#  'dog',
#  'airplane',
#  'cat',
#  'airplane',
#  'automobile',
#  'ship',
#  'automobile',
#  'cat',
#  'truck',
#  'frog',
#  'automobile',
#  'deer',
#  'horse',
#  'airplane',
#  'frog',
#  'horse',
#  'ship',
#  'truck',
#  'automobile',
#  'automobile',
#  'frog',
#  'frog',
#  'dog',
#  'cat',
#  'truck',
#  'automobile',
#  'truck',
#  'truck',
#  'deer',
#  'dog',
#  'automobile',
#  'airplane',
#  'airplane',
#  'frog',
#  'ship',
#  'automobile',
#  'truck',
#  'frog',
#  'truck',
#  'dog',
#  'deer',
#  'horse',
#  'ship',
#  'dog',
#  'automobile',
#  'bird',
#  'airplane',
#  'automobile',
#  'dog',
#  'ship',
#  'horse',
#  'truck',
#  'cat',
#  'ship',
#  'automobile',
#  'cat',
#  'ship',
#  ...]
